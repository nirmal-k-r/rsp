# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
results = model.predict("cat_dog.jpg")
result=results[0]
# Out:
# image 1/1 /Users/nirmal/Desktop/Development.nosync/RSP/training/cat_dog.jpg: 448x640 1 cat, 1 dog, 145.8ms
# Speed: 1.4ms preprocess, 145.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ...

# %%
data={}
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  conf = round(box.conf[0].item(), 2)
  data[class_id]=conf

print(data)
# Out:
# {'dog': 0.94, 'cat': 0.91}

# %%
import base64
from ultralytics import YOLO

model = YOLO("yolov8m.pt")


def predict(imgstring):
    # imgdata = base64.b64decode(imgstring)
    # filename = 'item.jpg'  
    # with open(filename, 'wb') as f:
    #     f.write(imgdata)
    results = model.predict(sugarImage)
    return results
        
sugarImage="data:image/jpeg;base64,..."

result=predict(sugarImage)
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/nirmal/Desktop/Development.nosync/RSP/training/test.ipynb Cell 3 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/Users/nirmal/Desktop/Development.nosync/RSP/training/test.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     return results
#      <a href='vscode-notebook-cell:/Users/nirmal/Desktop/Development.nosync/RSP/training/test.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> sugarImage="data:image/jpeg;base64,..."
# ---> <a href='vscode-notebook-cell:/Users/nirmal/Desktop/Development.nosync/RSP/training/test.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> result=predict(sugarImage)[0]
#      <a href='vscode-notebook-cell:/Users/nirmal/Desktop/Development.nosync/RSP/training/test.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> data={}
# ...

# %%
import base64
from PIL import Image
import io
import numpy as np
from ultralytics import YOLO

model = YOLO("yolov8m.pt")


def predict(imgstring):
    base64_string = imgstring.split(',')[1]
    # Convert base64 string to bytes
    image_bytes = base64.b64decode(base64_string)
    # Convert bytes to PIL Image object
    image = Image.open(io.BytesIO(image_bytes))
    # Convert PIL Image object to Numpy array
    results = model.predict(image)
    return results
        
sugarImage="data:image/jpeg;base64,..."

result=predict(sugarImage)[0]
data={}
first=None
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  conf = round(box.conf[0].item(), 2)
  data[class_id]=conf
  if first is None:
    first=class_id

print(data)
print(data[first])
# Out:
# 0: 448x640 1 baseball bat, 168.6ms
# Speed: 1.5ms preprocess, 168.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# {'baseball bat': 0.34}
# 0.34

# %%
print(data)
print(first, data[first])
# Out:
# {'baseball bat': 0.34}
# baseball bat 0.34
